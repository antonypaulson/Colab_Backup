# %% [markdown]
# # Example 4: Histogram
#
# Please see: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html  or https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# Question: how many data points to we have in total?

num_bins = 50

#plt.hist(x)
#plt.hist(x, num_bins)
plt.hist(x, num_bins, normed=1)
#plt.hist(x, num_bins, normed=True, facecolor='g')

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ: $\mu=100$, $\sigma=15$')

plt.show()

# %% [markdown]
# # Example 5: Bar Char
#
# Please see: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.bar.html

# %%
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
 
plt.bar(y_pos, performance, align='center')

plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %%
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
len(objects)
# Out:
# 6

# %% [markdown]
# # Example 6: Scatter Plot
#
# Please see: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # marker size in units of point **2. 

plt.scatter(x, y, s=area, c=colors, alpha=1) 
#except for x and y, all the other parameters are optional. 
#alpha is the alpha blending value, between 0 (transparent) and 1 (opaque).
# s is the marker size. The size of the markers will be random as defined in area. 
plt.show()

# %% [markdown]
# **Exercise: Can you get the last two month's stock price of Apple (APPL) using finance API?**

# %%
import pandas_datareader as pddr
import pandas as pd
import datetime
start_date=datetime.datetime(2018,9,1)
end_date=datetime.datetime.now()
DF=pddr.DataReader('AAPL','yahoo',start_date,end_date)
DF.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2018-09-04  229.179993  226.630005  228.410004  228.360001  27390100
# 2018-09-05  229.669998  225.100006  228.990005  226.869995  33333000
# 2018-09-06  227.350006  221.300003  226.229996  223.100006  34290000
# 2018-09-07  225.369995  220.710007  221.850006  221.300003  37619800
# 2018-09-10  221.850006  216.470001  220.949997  218.330002  39516500
#
#              Adj Close
# Date
# 2018-09-04  228.360001
# 2018-09-05  226.869995
# 2018-09-06  223.100006
# 2018-09-07  221.300003
# 2018-09-10  218.330002

# %% [markdown]
# Please plot the adjusted Close stock price using scatter plot. . Make x-axis named 'Date', and y-axis named 'Adjusted closing price ($)'.

# %%
#plt.plot(DF.index, DF['Adj Close'], c='b')
plt.scatter(DF.index, DF['Adj Close'],s=100, c='b', alpha=1) 
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.show()

# %% [markdown]
# ## Exercise:
#
# Can you figure out how to set the range of x (or y) axis in scatter plot?

# %%
plt.scatter(DF.index, DF['Adj Close'],s=100, c='b', alpha=1) 
plt.xlabel('Date')
plt.ylabel('Adjusted closing price ($)')
plt.xlim(DF.index.min(),DF.index.max())
plt.show()
